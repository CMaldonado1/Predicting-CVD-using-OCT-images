# %%
import torch
import numpy as np
import pandas as pd
import torchvision.transforms.functional as F
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from sklearn.decomposition import PCA
import torchvision.transforms as T
from oct_ml_vae_fc import VAE_OCT, classifier_oct, VAE_classifier_OCT  #_class
from pl_datamodule_vae_fc import OCT_DM, MM
from sklearn import preprocessing
import torch.nn as nn
from captum.attr import Occlusion, IntegratedGradients, LayerConductance
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
import sklearn.model_selection as skms
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, confusion_matrix, roc_curve, auc
from sklearn.tree import export_graphviz

# %%
random_seed = 295471
test_size = 0.2
train_size = 1-test_size

# %%
zs_be = pd.read_excel('zs_be_mtdt.xlsx')
X = zs_be.drop(['Vascular','ID'], axis=1)
y = zs_be['Vascular']

# %%
new_test_set1 = pd.read_excel('../new_test_set/new_test_set_1.xlsx')
#new_test_set = new_test_set1.sample(n=200)
#selected_columns2 = ['IDs', 'Vascular'] + [f"zl{i:03d}" for i in range(128)]
#zs_le_test = new_test_set[selected_columns2]
X_t = new_test_set1.drop(['Vascular','IDs'], axis=1)
y_t = new_test_set1['Vascular']

# %%
X.columns
# Out:
# Index(['Gender', 'DBP1', 'SBP1', 'BMI', 'Age', 'HbA1c', 'drinking', 'zl000',
#        'zl001', 'zl002',
#        ...
#        'zr118', 'zr119', 'zr120', 'zr121', 'zr122', 'zr123', 'zr124', 'zr125',
#        'zr126', 'zr127'],
#       dtype='object', length=263)

# %%
X_t.columns
# Out:
# Index(['zl000', 'zl001', 'zl002', 'zl003', 'zl004', 'zl005', 'zl006', 'zl007',
#        'zl008', 'zl009',
#        ...
#        'zr125', 'zr126', 'zr127', 'Gender', 'DBP1', 'SBP1', 'BMI', 'Age',
#        'HbA1c', 'drinking'],
#       dtype='object', length=263)

# %%
x_train = X.append(X_t)
y_train = y.append(y_t)
# Out:
# /tmp/ipykernel_3482469/775141070.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x_train = X.append(X_t)
# /tmp/ipykernel_3482469/775141070.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y_train = y.append(y_t)

# %%
x_train
# Out:
#      Gender      DBP1      SBP1       BMI       Age     HbA1c  drinking  \
# 0         1  0.500000  0.401575  0.276554  0.866667  0.182398       1.0
# 1         1  0.305556  0.314961  0.355754  0.066667  0.039541       1.0
# 2         0  0.527778  0.188976  0.505247  0.833333  0.135204       0.8
# 3         1  0.777778  0.566929  0.337695  0.666667  0.176020       1.0
# 4         1  0.597222  0.409449  0.327507  0.700000  0.147959       1.0
# ..      ...       ...       ...       ...       ...       ...       ...
# 787       0  0.294872  0.267176  0.253348  0.800000  0.319519       1.0
# 788       1  0.000000  0.251908  0.217729  0.600000  0.151070       1.0
# 789       1  0.192308  0.175573  0.306909  0.166667  0.183155       1.0
# 790       0  0.115385  0.183206  0.323246  0.866667  0.184492       1.0
# 791       0  0.294872  0.267176  0.472683  0.333333  0.168449       1.0
#
#         zl000     zl001     zl002  ...     zr118     zr119     zr120  \
# 0    0.013690  0.006705  0.041457  ... -0.071885 -0.009017 -0.009737
# 1   -0.030626 -0.058995  0.023517  ... -0.016741 -0.041040  0.024894
# 2    0.014472 -0.028770 -0.008231  ... -0.014079 -0.033425 -0.009103
# 3    0.024789  0.071516  0.021347  ... -0.037570  0.006645  0.030887
# 4    0.022011  0.029976 -0.020058  ... -0.035268  0.012078 -0.011655
# ..        ...       ...       ...  ...       ...       ...       ...
# 787  0.029209  0.023187 -0.047432  ... -0.046063  0.046340 -0.023661
# 788 -0.021675 -0.090961  0.012294  ... -0.058486  0.001976  0.054371
# 789  0.039529 -0.068100  0.024792  ... -0.037072  0.055662  0.005016
# 790 -0.026343  0.028728  0.012835  ... -0.060138  0.005667 -0.029552
# 791  0.015445  0.011576 -0.014474  ... -0.035659  0.018529 -0.039423
#
#         zr121     zr122     zr123     zr124     zr125     zr126     zr127
# 0    0.017275 -0.019784 -0.061393 -0.021526 -0.158654  0.027075  0.124533
# 1   -0.080791 -0.033292 -0.008517 -0.019734 -0.004313  0.026667  0.009094
# 2   -0.044072 -0.007639  0.002209 -0.012897 -0.114580 -0.035837 -0.086136
# 3   -0.004818  0.012219 -0.021693 -0.011989  0.014369 -0.023152 -0.044970
# 4    0.043828  0.009566  0.023805 -0.047647 -0.033496 -0.010518 -0.010113
# ..        ...       ...       ...       ...       ...       ...       ...
# 787 -0.022084 -0.003351 -0.016908 -0.019617  0.014337 -0.043428 -0.010053
# 788  0.011697 -0.014300 -0.006451  0.003091  0.013049 -0.026917 -0.060667
# 789  0.080396 -0.056501 -0.024046  0.004728 -0.171577 -0.006293  0.026352
# 790  0.004760  0.003989  0.019486 -0.023789 -0.028617 -0.074303 -0.023024
# 791 -0.106803 -0.001042 -0.022615  0.011529 -0.075293  0.006491 -0.049722
#
# [2016 rows x 263 columns]

# %%
rf_classifier = RandomForestClassifier()
rfe = RFE(estimator=rf_classifier, n_features_to_select=10)

# %%
X_selected = rfe.fit_transform(x_train, y_train)

# %%
selected_features = x_train.columns[rfe.support_]

# %%
X_selected1 = x_train[['BMI', 'zl005', 'zl054', 'zl066', 'zl075', 'zl121', 'zr002', 'zr007', 'zr067', 'zr072']]

# %%
X_t_selected = X_t[['BMI', 'zl005', 'zl054', 'zl066', 'zl075', 'zl121', 'zr002', 'zr007', 'zr067', 'zr072']]

# %%
features = X_selected1.columns.tolist()

# %%
X_train, X_test, y_train, y_test = skms.train_test_split(X_selected1, y_train, test_size=test_size, random_state=random_seed)
X_train_rows, y_train_rows = X_train.shape[0], y_train.shape[0]
X_test_rows, y_test_rows = X_test.shape[0], y_test.shape[0]
train_rows, test_rows = -1, -1

# %%
test_x = X_test.append(X_t_selected)
test_y = y_test.append(y_t)
# Out:
# /tmp/ipykernel_3482469/2248548446.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_x = X_test.append(X_t_selected)
# /tmp/ipykernel_3482469/2248548446.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_y = y_test.append(y_t)

# %%
test_x
# Out:
#            BMI     zl005     zl054     zl066     zl075     zl121     zr002  \
# 1061  0.261515 -0.013882 -0.002264  0.001982  0.009486 -0.085773 -0.012013
# 501   0.465114 -0.003017  0.006077 -0.027067 -0.066495 -0.110698 -0.020268
# 1211  0.311788 -0.007518 -0.045939  0.020161  0.025941  0.014069  0.031909
# 321   0.337389 -0.050714 -0.002518  0.009939 -0.018422 -0.011136  0.004072
# 238   0.393414 -0.030934  0.029781  0.049372 -0.030239  0.030929  0.040640
# ...        ...       ...       ...       ...       ...       ...       ...
# 787   0.253348  0.080584  0.011438  0.007119 -0.082704  0.072860  0.057329
# 788   0.217729 -0.023882  0.024817 -0.000369 -0.047161 -0.065519  0.011103
# 789   0.306909  0.014554  0.018408  0.022902  0.093054  0.077706  0.060029
# 790   0.323246  0.015558 -0.004257  0.037433 -0.039628  0.065862  0.016180
# 791   0.472683  0.000996 -0.041177 -0.071669 -0.005952 -0.012685 -0.019225
#
#          zr007     zr067     zr072
# 1061  0.026823 -0.034343 -0.043786
# 501  -0.008474  0.067523  0.033670
# 1211 -0.021460 -0.011663 -0.005162
# 321   0.036812  0.013703 -0.019371
# 238   0.002025 -0.006403 -0.034473
# ...        ...       ...       ...
# 787  -0.021366 -0.032464 -0.016299
# 788  -0.002290  0.027133 -0.014245
# 789   0.026809 -0.036112  0.019855
# 790  -0.016593 -0.006349 -0.026268
# 791   0.015983  0.000088  0.008482
#
# [1037 rows x 10 columns]

# %%
if X_train_rows == y_train_rows:
    train_rows = X_train_rows

if X_test_rows == y_test_rows:
    test_rows = X_test_rows

# %%
print(len(y_train[y_train==0]))
print(len(y_train[y_train==1]))
# Out:
# 1126
# 486

# %%
rows, cols = X_selected1.shape
print(f'> features = {len(features)}')
print(f'> training set = {train_rows} ({round(train_rows*1.0/rows,3)})')
print(f'> testing set = {test_rows} ({round(test_rows*1.0/rows,3)}) \n')
# Out:
# > features = 10
# > training set = 1612 (0.8)
# > testing set = 404 (0.2)

# %%
#----  random forest training with hyperparameter tuning
random_grid = {'n_estimators': [300, 400, 500],
               'criterion': ['gini', 'entropy'],
               'max_features': [0.25, 0.50, 0.75],
               'max_depth': [1],
               'min_samples_split': [150, 200, 250],
               'min_samples_leaf': [220, 230, 240],
               'bootstrap': [True, False],
               'class_weight': ['balanced'],
               'random_state': [random_seed]}

# %%
print('> Random Forest classifier...')
optimized_rfc = skms.RandomizedSearchCV(estimator = RandomForestClassifier(), 
                                        param_distributions = random_grid, 
                                        n_iter = 200, 
                                        cv = 5, 
                                        scoring=['roc_auc'],
                                        refit ='roc_auc',
                                        verbose=1, 
                                        n_jobs = -1,
                                        random_state = random_seed, 
                                        return_train_score= True)
# Out:
# > Random Forest classifier...

# %%
optimized_rfc.fit(X_train, np.ravel(y_train))
print('\n')
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits

# %%
#----  obtaining results of the grid run
cv_results = optimized_rfc.cv_results_
cv_results_df = pd.DataFrame(cv_results)

# %%
cv_results_df[['split0_test_roc_auc', 'split1_test_roc_auc', 'split2_test_roc_auc', 'mean_test_roc_auc', 'std_test_roc_auc', 'rank_test_roc_auc']].sort_values(by ='rank_test_roc_auc')
# Out:
#      split0_test_roc_auc  split1_test_roc_auc  split2_test_roc_auc  \
# 67              0.557340             0.604399             0.641833
# 2               0.557340             0.604399             0.641833
# 172             0.557203             0.603946             0.641695
# 194             0.557203             0.603946             0.641695
# 151             0.556519             0.605170             0.640229
# ..                   ...                  ...                  ...
# 136             0.541625             0.581905             0.616930
# 140             0.541625             0.581905             0.616930
# 23              0.541625             0.581905             0.616930
# 6               0.541625             0.581905             0.616930
# 199             0.541625             0.581905             0.616930
#
#      mean_test_roc_auc  std_test_roc_auc  rank_test_roc_auc
# 67            0.618089          0.033850                  1
# 2             0.618089          0.033850                  1
# 172           0.617952          0.033923                  3
# 194           0.617952          0.033923                  3
# 151           0.617896          0.033995                  5
# ..                 ...               ...                ...
# 136           0.598594          0.032859                189
# 140           0.598594          0.032859                189
# 23            0.598594          0.032859                189
# 6             0.598594          0.032859                189
# 199           0.598594          0.032859                189
#
# [200 rows x 6 columns]

# %%
cv_results_df[['mean_train_roc_auc', 'mean_test_roc_auc', 'rank_test_roc_auc']].sort_values(by ='rank_test_roc_auc')
# Out:
#      mean_train_roc_auc  mean_test_roc_auc  rank_test_roc_auc
# 67             0.666892           0.618089                  1
# 2              0.666892           0.618089                  1
# 172            0.666917           0.617952                  3
# 194            0.666917           0.617952                  3
# 151            0.667605           0.617896                  5
# ..                  ...                ...                ...
# 136            0.638791           0.598594                189
# 140            0.638791           0.598594                189
# 23             0.638791           0.598594                189
# 6              0.638791           0.598594                189
# 199            0.638791           0.598594                189
#
# [200 rows x 3 columns]

# %%
best_params = optimized_rfc.best_params_
best_score = optimized_rfc.best_score_
print(f'> best hyperparameters = {best_params}')
print(f'> best cv score = {best_score} \n')
# Out:
# > best hyperparameters = {'random_state': 295471, 'n_estimators': 500, 'min_samples_split': 150, 'min_samples_leaf': 240, 'max_features': 0.25, 'max_depth': 1, 'criterion': 'entropy', 'class_weight': 'balanced', 'bootstrap': True}
# > best cv score = 0.6180888729180204

# %%
y_train_pred = optimized_rfc.predict(X_train)
y_train_pred_proba = optimized_rfc.predict_proba(X_train)[:, 1]
accuracy_train = round(accuracy_score(y_train, y_train_pred),3)
roc_auc_train = round(roc_auc_score(y_train, y_train_pred_proba),3)
recall_train = round(recall_score(y_train, y_train_pred),3)
precision_train = round(precision_score(y_train, y_train_pred),3)

# %%
y_pred = optimized_rfc.predict(X_test)
y_pred_proba = optimized_rfc.predict_proba(X_test)[:, 1]
accuracy_test = round(accuracy_score(y_test, y_pred),3)
roc_auc_test = round(roc_auc_score(y_test, y_pred_proba),3)
recall_test = round(recall_score(y_test, y_pred),3)
precision_test = round(precision_score(y_test, y_pred),3)
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

# %%
print('> evaluation metrics \n')
print('%-10s %20s %10s' % ('metric','training','testing'))
print('%-10s %20s %10s' % ('roc auc', roc_auc_train, roc_auc_test))
print('%-10s %20s %10s' % ('accuracy', accuracy_train, accuracy_test))
print('%-10s %20s %10s' % ('recall', recall_train, recall_test))
print('%-10s %20s %10s' % ('precision', precision_train, precision_test))
print('\n')
# Out:
# > evaluation metrics
#
# metric                 training    testing
# roc auc                   0.664      0.575
# accuracy                  0.632      0.567
# recall                    0.582      0.532
# precision                 0.421      0.366

# %%
print('> confusion matrix \n')
print(tn, fp, fn, tp)
print('\n')
# Out:
# > confusion matrix
#
# 162 116 59 67

# %%
print('> confusion matrix \n')
print(tn, fp, fn, tp)
print('\n')
# Out:
# > confusion matrix
#
# 189 89 37 89

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

# %%
fpr_tpr = pd.DataFrame(data=np.array([fpr, tpr]).T, columns=["fpr", "tpr"])
fpr_tpr.to_excel("fpr_tpr_be_mtdt.xlsx", index=False)

# %%
#----  getting feature importance
optimized_rfc_importance = optimized_rfc.best_estimator_.feature_importances_
indices = np.argsort(-1*optimized_rfc_importance)
rfc_feature_imp_df = pd.DataFrame(optimized_rfc_importance, index=pd.DataFrame(X_test).columns, columns=['importance'])
rfc_feature_imp_df.sort_values(by='importance', ascending=False, inplace=True)

# %%
# summarize feature importance
print('> feature importance')
for i in indices:
    print('%-8s %-20s' % (round(optimized_rfc_importance[i], 4), f'({features[i]})'))
# Out:
# > feature importance
# 0.22     (BMI)
# 0.142    (zr002)
# 0.13     (zl121)
# 0.122    (zl054)
# 0.098    (zr067)
# 0.092    (zl005)
# 0.09     (zl066)
# 0.056    (zl075)
# 0.044    (zr007)
# 0.006    (zr072)

# %%
# feature importance plot
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.barh(range(len(indices)), optimized_rfc_importance[indices], align='center')
ax.set_yticks(range(len(indices)))
#ax.set_yticklabels(["RFNL-R", "RFNL-L","ISOS-RPE" ], fontsize=12)
ax.set_yticklabels([features[i] for i in indices], fontsize=12)
ax.invert_yaxis()
ax.set_title('Feature Importances', fontsize=18, fontweight='bold')
ax.set_xlabel('Relative Importance', fontsize=18, fontweight='bold')
ax.set_ylabel('Features', fontsize=18, fontweight='bold')
ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_color('black')
ax.spines['bottom'].set_linewidth(2)
ax.grid(True)
#fig.savefig('feature_importance_plot.png')

# %%
# ROC curve
# print(plt.style.available)
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', label='Chance', alpha=.8)
ax.set_title('ROC Curve (auc = %0.3f)' % roc_auc, fontsize=22, fontweight='bold')
ax.set_xlabel('False Positive Rate', fontsize=16, fontweight='bold')
ax.set_ylabel('True Positive Rate', fontsize=16, fontweight='bold')
ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_color('black')
ax.spines['bottom'].set_linewidth(2)
ax.grid(True)
#fig.savefig('roc_plot.png')

# %%
from sklearn import tree

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 1219    1
# 1220    0
# 1221    0
# 1222    0
# 1223    0
# Name: Vascular, Length: 1224, dtype: int64

# %%
best_rf_model = optimized_rfc.best_estimator_
best_rf_model
# Out:
# RandomForestClassifier(max_depth=1, max_features=0.25, min_samples_leaf=220,
#                        min_samples_split=200, n_estimators=300,
#                        random_state=295471)

# %%
tree_to_plot = best_rf_model.estimators_[0]
tree_to_plot
# Out:
# DecisionTreeClassifier(max_depth=1, max_features=0.25, min_samples_leaf=220,
#                        min_samples_split=200, random_state=647778894)

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=800)
tree.plot_tree(tree_to_plot,
               feature_names=X_selected1.columns, 
               class_names=['non-CVD', 'CVD'],
               filled=True)
fig.savefig('rf_individualtree.png')
